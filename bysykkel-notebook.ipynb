# %%
import pandas as pd
import numpy as np
import os
import folium
from branca.colormap import linear
from folium.plugins import HeatMap

# %% [markdown]
# # Analyzing City Bike Data in Bergen, Norway (2023)
#
# This notebook uses data from [Bergen bysykkel historiske data](https://bergenbysykkel.no/apne-data/historisk) for january to december 2023.
#
# The dataset contains information such as the start and end times of bike rides, the duration of rides, start and end station IDs, station names, and geographical coordinates.
#
# ## Overview of Analysis
#
# 1. **Data Preparation**: We begin by loading and preprocessing the data, concatenating monthly data files into a single dataframe.
#
# 2. **Visualizing Popular Routes**: We identify and visualize the 100 most traveled routes in Bergen based on bike sharing data. These visualizations provide insights into the most popular bike routes and help understand the patterns of bike usage in the city.
#
# 3. **Visualizing Least Traveled Routes**: Similarly, we visualize the 100 least traveled routes, which might indicate underutilized areas or less popular bike routes.
#
# 4. **Heatmap of Starting Stations**: We create a heatmap showing the distribution of bike ride start locations across the city. This visualization helps identify areas with high bike usage density.
#
# Throughout the notebook, we use the `folium` library for creating interactive maps to visualize geographical data.

# %% [markdown]
# ## Loading the data

# %%
filenames = [f"data/{month:02d}.csv" for month in range(1, 13)]

dataframes = []

for filename in filenames:
    if os.path.exists(filename):
        df = pd.read_csv(filename)
        dataframes.append(df)
    else:
        print(f"File not found: {filename}")

combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df.head()
# Out:
#                          started_at                          ended_at  \
# 0  2023-01-01 04:22:50.614000+00:00  2023-01-01 04:33:19.884000+00:00
# 1  2023-01-01 04:31:33.724000+00:00  2023-01-01 04:33:21.525000+00:00
# 2  2023-01-01 04:33:41.500000+00:00  2023-01-01 04:44:24.625000+00:00
# 3  2023-01-01 05:55:30.388000+00:00  2023-01-01 05:59:17.644000+00:00
# 4  2023-01-01 05:59:33.946000+00:00  2023-01-01 06:03:47.999000+00:00
#
#    duration  start_station_id start_station_name start_station_description  \
# 0       629               150             Torget              Ved busstopp
# 1       107              1894   Kong Oscars gate   Ved Kong Oscars gate 36
# 2       643              1894   Kong Oscars gate   Ved Kong Oscars gate 36
# 3       227               797   John Lunds plass          John Lunds plass
# 4       254                22            Skur 11          Nord for skur 11
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               60.395878                 5.325284            1896
# 1               60.393323                 5.330654            1894
# 2               60.393323                 5.330654             809
# 3               60.388247                 5.324558              22
# 4               60.396384                 5.324169             812
#
#       end_station_name     end_station_description  end_station_latitude  \
# 0  Takhagen på Nordnes  På taket av Nordneshallen              60.398865
# 1     Kong Oscars gate     Ved Kong Oscars gate 36             60.393323
# 2      Skutevikstorget       På sørsiden av torget             60.402229
# 3              Skur 11            Nord for skur 11             60.396384
# 4     Hans Hauges gate         Jens Rolfens gate 6             60.401906
#
#    end_station_longitude
# 0               5.306411
# 1               5.330654
# 2               5.320745
# 3               5.324169
# 4               5.324748

# %%
combined_df.tail()
# Out:
#                               started_at                          ended_at  \
# 467856  2023-12-31 21:37:56.593000+00:00  2023-12-31 21:46:08.219000+00:00
# 467857  2023-12-31 21:38:05.944000+00:00  2023-12-31 21:42:35.790000+00:00
# 467858  2023-12-31 21:52:34.239000+00:00  2023-12-31 22:02:00.744000+00:00
# 467859  2023-12-31 22:13:49.387000+00:00  2023-12-31 22:25:26.481000+00:00
# 467860  2023-12-31 22:25:37.636000+00:00  2023-12-31 22:38:15.701000+00:00
#
#         duration  start_station_id    start_station_name  \
# 467856       491                49   Studentsenteret UiB
# 467857       269               156     Allehelgens plass
# 467858       566              2322  Høyteknologisenteret
# 467859       697               818      Vågsallmenningen
# 467860       758               219     Jonsvollkvartalet
#
#             start_station_description  start_station_latitude  \
# 467856  ved Parkveien / Olaf Ryes vei               60.387198
# 467857                ved Politihuset               60.392651
# 467858           Utenfor hovedinngang               60.381750
# 467859                  Ved Husfliden               60.393690
# 467860                 Jonsvollsgaten               60.392677
#
#         start_station_longitude  end_station_id   end_station_name  \
# 467856                 5.322980             212          Klosteret
# 467857                 5.328977             219  Jonsvollkvartalet
# 467858                 5.331699              36   Torgallmenningen
# 467859                 5.326581               5      Moxy Hotellet
# 467860                 5.317308             640     Damsgårdsveien
#
#                     end_station_description  end_station_latitude  \
# 467856                         Strangehagen             60.395138
# 467857                       Jonsvollsgaten             60.392677
# 467858  Valkendorfsgaten / Torgallmenningen             60.392918
# 467859             På sørsiden av hotellet              60.378783
# 467860                 Ved inngang Bunnpris             60.381512
#
#         end_station_longitude
# 467856               5.314947
# 467857               5.317308
# 467858               5.323669
# 467859               5.333327
# 467860               5.319435

# %% [markdown]
# ## Creating a new dataframe and visualizing the most popular routes
#
# Before we can visualize the most popular routes, we first need to create a new dataframe containing the route name along with the starting and ending id. We also want to count the number of times the route is traveled.

# %%
combined_df['route_name'] = combined_df['start_station_name'] + " to " + combined_df['end_station_name']

combined_df['start_id'] = combined_df['start_station_id']
combined_df['end_id'] = combined_df['end_station_id']

route_details = combined_df.groupby(['route_name', 'start_id', 'end_id']).size().reset_index(name='count')
route_details_sorted = route_details.sort_values(by='count', ascending=False)
route_details_sorted = pd.merge(route_details_sorted, combined_df[['start_id', 'end_id', 'start_station_latitude', 'start_station_longitude', 'end_station_latitude', 'end_station_longitude']], 
                                how='left', 
                                left_on=['start_id', 'end_id'], 
                                right_on=['start_id', 'end_id'])

route_details_sorted = route_details_sorted.drop_duplicates(subset=['route_name', 'start_id', 'end_id'])

print(route_details_sorted.head())
# Out:
#                                   route_name  start_id  end_id  count  \
# 0               Torgallmenningen to Nykirken        36     814   1831
# 1831      Torgallmenningen to C. Sundts gate        36     138   1629
# 3460  Busstasjonen 1 Nord to Møllendalsplass       789     220   1617
# 5077            Nykirken to Torgallmenningen       814      36   1531
# 6608  Møllendalsplass to Busstasjonen 1 Nord       220     789   1350
#
#       start_station_latitude  start_station_longitude  end_station_latitude  \
# 0                  60.392918                 5.323669             60.396949
# 1831               60.392918                 5.323669             60.399475
# 3460               60.388910                 5.333817             60.379686
# 5077               60.396949                 5.313495             60.392918
# 6608               60.379686                 5.351994             60.388910
#
#       end_station_longitude
# 0                  5.313495
# 1831               5.308762
# 3460               5.351994
# 5077               5.323669
# 6608               5.333817

# %% [markdown]
# ## Visualizing the 100 most traveled routes for 2023

# %%
m = folium.Map(location=[60.392918, 5.323669], zoom_start=13)  # Use the first route's start coordinates as the initial location
colormap = linear.inferno.scale(route_details_sorted['count'].min(), route_details_sorted['count'].max())

for index, row in route_details_sorted.head(100).iterrows():
    start_coords = (row['start_station_latitude'], row['start_station_longitude'])
    end_coords = (row['end_station_latitude'], row['end_station_longitude'])
    route_color = colormap(row['count'])
    folium.PolyLine(locations=[start_coords, end_coords], color=route_color, weight=2, popup=f"Route: {row['route_name']} ({row['count']} counts)").add_to(m)

colormap.add_to(m)
title_html = '<h3 align="center" style="font-size:16px"><b>The 100 most traveled routes for 2023</b></h3>'
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46a94141671b2e36cf5d2ae8f7a9fb60 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;The 100 most traveled routes for 2023&lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46a94141671b2e36cf5d2ae8f7a9fb60&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46a94141671b2e36cf5d2ae8f7a9fb60 = L.map(
#                 &quot;map_46a94141671b2e36cf5d2ae8f7a9fb60&quot;,
#                 {
#                     center: [60.392918, 5.323669],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8fdfee9928eac9901517f36b62b6ce8b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8fdfee9928eac9901517f36b62b6ce8b.addTo(map_46a94141671b2e36cf5d2ae8f7a9fb60);
#
#
#             var poly_line_f39e43d2c8dfa033991e29671fa5e475 = L.polyline(
#                 [[60.39291769029913, 5.323669092809325], [60.396949224333255, 5.313494727727743]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fcffa4ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#fcffa4ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_46a94141671b2e36cf5d2ae8f7a9fb60);
#
#
#         var popup_7dbd9f56a41307b6e7185a280b472d34 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be17cd2e860c898e1e9d99f3cd210020 = $(`&lt;div id=&quot;html_be17cd2e860c898e1e9d99f3cd210020&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Route: Torgallmenningen to Nykirken (1831 counts)&lt;/div&gt;`)[0];
#                 popup_7dbd9f56a41307b6e7185a280b472d34.setContent(html_be17cd2e860c898e1e9d99f3cd210020);
#
#
#
#         poly_line_f39e43d2c8dfa033991e29671fa5e475.bindPopup(popup_7dbd9f56a41307b6e7185a280b472d34)
#         ;
#
#
#
#
#             var poly_line_7bf24038bf7c68bb2f3c5a422e29b08e = L.polyline(
#                 [[60.39291769029913, 5.323669092809325], [60.39947506336557, 5.308762204430565]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f7d33fff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#f7d33fff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_46a94141671b2e36cf5d2ae8f7a9fb60);
#
#
#         var popup_30714e18701bd55954443df57cd5b760 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04a54fd0fe0cd85df2ca5354f41a0d06 = $(`&lt;div id=&quot;html_04a54fd0fe0cd85df2ca5354f41a0d06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Route: Torgallmenningen to C. Sundts gate (1629 counts)&lt;/div&gt;`)[0];
#                 popup_30714e18701bd55954443df57cd5b760.setContent(html_04a54fd0fe0cd85df2ca5354f41a0d06);
#
#
#
#         poly_line_7bf24038bf7c68bb2f3c5a422e29b08e.bindPopup(popup_30714e18701bd55954443df57cd5b760)
#         ;
#
#
#
#
#             var poly_line_fd2030f05be3a2568f448d12239942f1 = L.polyline(
#                 [[60.38890977889046, 5.333817119783134], [60.379685765470725, 5.3519936304809335]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f8cf3bff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#f8cf3bff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_46a94141671b2e36cf5d2ae8f7a9fb60);
#
#
#         var popup_3321068ed454c76b4399882a516b2441 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af23b70f491774717f02557faeb61ac3 = $(`&lt;div id=&quot;html_af23b70f491774717f02557faeb61ac3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Route: Busstasjonen 1 Nord to Møllendalsplass (1617 co

# %% [markdown]
# ## Visualizing the 100 least traveled routes for 2023

# %%
m = folium.Map(location=[60.392918, 5.323669], zoom_start=12)  # Use the first route's start coordinates as the initial location
colormap = linear.YlOrRd_04.scale(route_details_sorted['count'].min(), route_details_sorted['count'].max())

for index, row in route_details_sorted.tail(100).iterrows():
    start_coords = (row['start_station_latitude'], row['start_station_longitude'])
    end_coords = (row['end_station_latitude'], row['end_station_longitude'])
    route_color = colormap(row['count'])
    folium.PolyLine(locations=[start_coords, end_coords], color=route_color, weight=1, popup=f"Route: {row['route_name']} ({row['count']} counts)").add_to(m)

colormap.add_to(m)

title_html = '<h3 align="center" style="font-size:16px"><b>The 100 least traveled routes for 2023</b></h3>'
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21ac4972d5a4296e1b18996d9a05a423 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;The 100 least traveled routes for 2023&lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21ac4972d5a4296e1b18996d9a05a423&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21ac4972d5a4296e1b18996d9a05a423 = L.map(
#                 &quot;map_21ac4972d5a4296e1b18996d9a05a423&quot;,
#                 {
#                     center: [60.392918, 5.323669],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1422b869679487c2b31def43dd1a6043 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1422b869679487c2b31def43dd1a6043.addTo(map_21ac4972d5a4296e1b18996d9a05a423);
#
#
#             var poly_line_4ae9f9751ef0a9dadd013abdb6986771 = L.polyline(
#                 [[60.380044402639385, 5.350823586678217], [60.40175764348675, 5.316562300638424]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffffb2ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffffb2ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_21ac4972d5a4296e1b18996d9a05a423);
#
#
#         var popup_950d4b764d4f05666635c1c26b7d2beb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a36ab87a54d32efea7c08a77b9dc2f9d = $(`&lt;div id=&quot;html_a36ab87a54d32efea7c08a77b9dc2f9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Route: Møllestranden to Bontelabo (1 counts)&lt;/div&gt;`)[0];
#                 popup_950d4b764d4f05666635c1c26b7d2beb.setContent(html_a36ab87a54d32efea7c08a77b9dc2f9d);
#
#
#
#         poly_line_4ae9f9751ef0a9dadd013abdb6986771.bindPopup(popup_950d4b764d4f05666635c1c26b7d2beb)
#         ;
#
#
#
#
#             var poly_line_3fd713b333146f9f3ab66f1ed0d27b08 = L.polyline(
#                 [[60.38658166593217, 5.327978744635743], [60.34877037988127, 5.288172686196418]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffffb2ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffffb2ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_21ac4972d5a4296e1b18996d9a05a423);
#
#
#         var popup_012887a23859ceafd142bf59672f656e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aaec3b821a67fc007797249ea943393f = $(`&lt;div id=&quot;html_aaec3b821a67fc007797249ea943393f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Route: Fosswinckels gate to Oasen (1 counts)&lt;/div&gt;`)[0];
#                 popup_012887a23859ceafd142bf59672f656e.setContent(html_aaec3b821a67fc007797249ea943393f);
#
#
#
#         poly_line_3fd713b333146f9f3ab66f1ed0d27b08.bindPopup(popup_012887a23859ceafd142bf59672f656e)
#         ;
#
#
#
#
#             var poly_line_3fcc42fe62274b7c928b7daa39ce1732 = L.polyline(
#                 [[60.38658238047282, 5.326041074182427], [60.39705738914522, 5.314548482139799]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffffb2ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#ffffb2ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_21ac4972d5a4296e1b18996d9a05a423);
#
#
#         var popup_297b1ad263cfa6e0e623e05a618b0fe8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e162f0c66fe8d691a1c7b491eee2d822 = $(`&lt;div id=&quot;html_e162f0c66fe8d691a1c7b491eee2d822&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Route: Strømgaten to Nykirkekaien (1 counts)&lt;/div&gt;`)[0];

# %% [markdown]
# ## Visualizing the most popular starting stations

# %%
m = folium.Map(location=[60.392918, 5.323669], zoom_start=13)
start_coordinates = route_details_sorted[['start_station_latitude', 'start_station_longitude']].values.tolist()
heat_map_layer = HeatMap(start_coordinates)
heat_map_layer.add_to(m)
title_html = '<h3 align="center" style="font-size:16px"><b>Heatmap of Route Start Coordinates</b></h3>'
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00c36f786f6ec5af95b9e0f7e3c79e3b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Heatmap of Route Start Coordinates&lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00c36f786f6ec5af95b9e0f7e3c79e3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00c36f786f6ec5af95b9e0f7e3c79e3b = L.map(
#                 &quot;map_00c36f786f6ec5af95b9e0f7e3c79e3b&quot;,
#                 {
#                     center: [60.392918, 5.323669],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a3dad673a20ca16686eec56a1d8efcb8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a3dad673a20ca16686eec56a1d8efcb8.addTo(map_00c36f786f6ec5af95b9e0f7e3c79e3b);
#
#
#             var heat_map_c1a45db8b3146aef58d52db57be01672 = L.heatLayer(
#                 [[60.39291769029913, 5.323669092809325], [60.39291769029913, 5.323669092809325], [60.38890977889046, 5.333817119783134], [60.396949224333255, 5.313494727727743], [60.379685765470725, 5.3519936304809335], [60.38668149584837, 5.3309780770646], [60.39947506336557, 5.308762204430565], [60.39514386434325, 5.320002322335455], [60.39947506336557, 5.308762204430565], [60.38316244112318, 5.324053067317891], [60.39587808663882, 5.325283812313046], [60.37178687508714, 5.349552885719248], [60.391123958982405, 5.325713785893413], [60.38316244112318, 5.324053067317891], [60.39222475946063, 5.314881116119068], [60.38967202352878, 5.3336050852019525], [60.379685765470725, 5.3519936304809335], [60.37831673774707, 5.350897458652753], [60.382254745562825, 5.3323324699108525], [60.395070112977045, 5.31879835082907], [60.391123958982405, 5.325713785893413], [60.379685765470725, 5.3519936304809335], [60.39291769029913, 5.323669092809325], [60.396949224333255, 5.313494727727743], [60.38543124330305, 5.337431780062616], [60.396949224333255, 5.313494727727743], [60.38668149584837, 5.3309780770646], [60.38543124330305, 5.337431780062616], [60.37514055132067, 5.338517421420761], [60.39375532002469, 5.3217920958013565], [60.38151150199543, 5.319435364152128], [60.396949224333255, 5.313494727727743], [60.37178687508714, 5.349552885719248], [60.382254745562825, 5.3323324699108525], [60.396949224333255, 5.313494727727743], [60.39947506336557, 5.308762204430565], [60.379685765470725, 5.3519936304809335], [60.390414110522414, 5.332650453823391], [60.39375532002469, 5.3217920958013565], [60.39587808663882, 5.325283812313046], [60.39267683527631, 5.317308285189142], [60.395070112977045, 5.31879835082907], [60.39947506336557, 5.308762204430565], [60.379685765470725, 5.3519936304809335], [60.39291769029913, 5.323669092809325], [60.37831673774707, 5.350897458652753], [60.396949224333255, 5.313494727727743], [60.396949224333255, 5.313494727727743], [60.38316244112318, 5.324053067317891], [60.396949224333255, 5.313494727727743], [60.39705738914522, 5.314548482139799], [60.379685765470725, 5.3519936304809335], [60.38151150199543, 5.319435364152128], [60.3906427466302, 5.324397430398562], [60.41294568274233, 5.320870309021842], [60.408582102784685, 5.322648583141813], [60.38705878935416, 5.335633911730724], [60.38026271377996, 5.323223146883635], [60.391123958982405, 5.325713785893413], [60.382254745562825, 5.3323324699108525], [60.379685765470725, 5.3519936304809335], [60.39291769029913, 5.323669092809325], [60.39587808663882, 5.325283812313046], [60.379685765470725, 5.3519936304809335], [60.39587808663882, 5.325283812313046], [60.39375532002469, 5.3217920958013565], [60.390174061139966, 5.324792207669702], [60.391123958982405, 5.325713785893413], [60.39622446162616, 5.315384703788823], [60.376082994809856, 5.339851409058042], [60.38151150199543, 5.319435364152128], [60.384467341026586, 5.310007717995973], [60.37178687508714, 5.349552885719248], [60.38668149584837, 5.3309780770646], [60.39291769029913, 5.323669092809325], [60.391983600413376, 5.32661819461282], [60.390414110522414, 5.332650453823391], [60.39587808663882, 5.325283812313046], [60.37802198798124, 5.329383048102329], [60.382254745562825, 5.3323324699108525], [60.379685765470725, 5.3519936304809335], [60.395070112977045, 5.31879835082907], [60.38246949877819, 5.32609348920866], [60.39987652272946, 5.304686307890734], [60.37810721367397, 5.331020769519228], [60.38316244112318, 5.324053067317891], [60.38890977889046, 5.333817119783134], [60.38316244112318, 5.324053067317891], [60.39947506336557, 5.308762204430565], [60.379685765470725, 5.3519936304809335], [60.39587808663882, 5.325283812313046], [60.37802198798124, 5.329383048102329], [60.37831673774707, 5.350897458652753], [60.378107213673
